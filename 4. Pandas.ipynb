# %% [markdown]
# ## Датафреймы Pandas

# %% [markdown]
# ### Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as skl

# %% [markdown]
# ### Создание датафрейма при помощи массивов

# %%
col = ['Name', 'Drink', 'Price']

d = [
    ['Helena', 'Cocktail', 150],
    ['Peter', 'Beer', 70],
    ['Nick', 'Beer', 210],
    ['Kate', 'Mojito', 100]
    ]

#ind = np.arange(1, len(d)+1)
df = pd.DataFrame(columns = col,
                  data=d,
                 # index = ind
                 )
df
# Out:
#      Name     Drink  Price
# 0  Helena  Cocktail    150
# 1   Peter      Beer     70
# 2    Nick      Beer    210
# 3    Kate    Mojito    100

# %% [markdown]
# ### Действия с датафреймами

# %%
# Локализация столбцов
df0 = df[['Name', 'Price']]
df0
# Out:
#      Name  Price
# 0  Helena    150
# 1   Peter     70
# 2    Nick    210
# 3    Kate    100

# %%
# Локализация строк (по индексу)
df.loc[[2,3]]

# Локализация строк (по условию)
df.loc[(df['Price'] >= 100) & (df['Name'] != 'Nick')]
# Out:
#      Name     Drink  Price
# 0  Helena  Cocktail    150
# 3    Kate    Mojito    100

# %%
# Добавление столбцов
df['Taxi'] = ['yes', 'yes', 'no', 'yes']
df
# Out:
#      Name     Drink  Price Taxi
# 0  Helena  Cocktail    150  yes
# 1   Peter      Beer     70  yes
# 2    Nick      Beer    210   no
# 3    Kate    Mojito    100  yes

# %%
# Добавление строк
df.loc[len(df)] = ['Maria', 'Juice', 50, 'no']
df
# Out:
#      Name     Drink  Price Taxi
# 0  Helena  Cocktail    150  yes
# 1   Peter      Beer     70  yes
# 2    Nick      Beer    210   no
# 3    Kate    Mojito    100  yes
# 4   Maria     Juice     50   no

# %%
# Удаление столбцов
df.drop(columns = ['Taxi', 'Name'])
# Out:
#       Drink  Price
# 0  Cocktail    150
# 1      Beer     70
# 2      Beer    210
# 3    Mojito    100
# 4     Juice     50

# %%
# Удаление строк (по индексу)
df.drop([1,3])
# Out:
#      Name     Drink  Price Taxi
# 0  Helena  Cocktail    150  yes
# 2    Nick      Beer    210   no
# 4   Maria     Juice     50   no

# %%
# Удаление строк (по условию)
df.loc[df['Drink'] != 'Beer']
# Out:
#      Name     Drink  Price Taxi
# 0  Helena  Cocktail    150  yes
# 3    Kate    Mojito    100  yes
# 4   Maria     Juice     50   no

# %% [markdown]
# ### Чтение датафреймов из файлов CSV

# %%
ds_titanic = pd.read_csv('titanic_train.csv', sep = ',')

# %%
# Пропуски данных меняем на 0
ds_titanic.fillna(0)
# Out:
#      Survived  Pclass                                               Name
# 0           0       3                             Mr. Owen Harris Braund  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 647         0       3                                   Mr. Mito Mitkoff
# 648         1       2                                 Miss. Elsie Doling
# 649         0       3                      Mr. Johannes Halvorsen Kalvik
# 650         1       3                               Miss. Hanora O'Leary
# 651         0       3                               Miss. Hanora Hegarty
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0      male  22.0                        1                        0   7.2500
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 4      male  35.0                        0                        0   8.0500
# ..      ...   ...                      ...                      ...      ...
# 647    male  23.0                        0                        0   7.8958
# 648  female  18.0                        0                        1  23.0000
# 649    male  21.0                        0                        0   8.4333
# 650  female  16.0                        0                        0   7.8292
# 651  female  18.0                        0                        0   6.7500
#
# [652 rows x 8 columns]

# %%
#Замена строковых значений на числовые (метод replace)
ds_titanic = ds_titanic.replace({'Sex': {"male": 1, "female":0}})

# %% [markdown]
# ### Создание массивов numpy из dataframe

# %%
X = ds_titanic.drop(columns = ['Name', 'Age']).to_numpy()
y = ds_titanic[["Age"]].to_numpy()

# %% [markdown]
# ### Построение и обучение регрессионной модели

# %%
model=skl.LinearRegression()
model.fit(X,y)
model.score(X,y)
# Out:
# 0.29038418359602425

# %% [markdown]
# ### Прогноз целевой функции на новых данных

# %%
ds_test = pd.read_csv('titanic_test.csv', sep = ',')
ds_test.fillna(0)
ds_test = ds_test.replace({'Sex': {"male": 1, "female":0}})

# %%
X_test = ds_test.drop(columns = ['Name', 'Age']).to_numpy()
y_test = ds_test[["Age"]].to_numpy()
model.score(X_test,y_test)
# Out:
# 0.19613266325507162

# %%
model.predict(X_test)
# Out:
# array([[29.45468477],
#        [29.25758243],
#        [23.59691677],
#        [36.90688455],
#        [39.91702785],
#        [31.06457675],
#        [29.26735722],
#        [44.44714129],
#        [29.26341117],
#        [20.73456277],
#        [29.45468477],
#        [36.90688455],
#        [29.25934271],
#        [29.25533546],
#        [34.90128523],
#        [25.7408663 ],
#        [40.7769608 ],
#        [36.94331412],
#        [31.66959243],
#        [37.09631833],
#        [29.25934271],
#        [29.25533546],
#        [23.35355154],
#        [15.00849598],
#        [30.49095898],
#        [28.61567697],
#        [38.46462103],
#        [29.23821356],
#        [ 9.01036353],
#        [31.61654187],
#        [29.95278514],
#        [14.02693796],
#        [29.22443152],
#        [29.25903962],
#        [34.2385753 ],
#        [35.46680953],
#        [21.67528418],
#        [23.31209939],
#        [29.26735722],
#        [44.43311591],
#        [36.89959863],
#        [29.25533546],
#        [23.38427479],
#        [38.29275032],
#        [29.26116419],
#        [32.34356484],
#        [39.19964889],
#        [26.89745803],
#        [29.25982795],
#        [25.97288658],
#        [36.71745076],
#        [31.02392306],
#        [39.19964889],
#        [36.73596163],
#        [19.00171226],
#        [38.22295565],
#        [44.43311591],
#        [35.53966868],
#        [29.23444965],
#        [36.90688455],
#        [29.26116419],
#        [35.62886688],
#        [31.06763855],
#        [29.25934271],
#        [29.11359932],
#        [25.98454404],
#        [36.90688455],
#        [36.90688455],
#        [35.52363967],
#        [29.24641021],
#        [21.05872821],
#        [23.38421358],
#        [33.43214872],
#        [25.33347144],
#        [35.86474837],
#        [29.09887044],
#        [37.09631833],
#        [36.90688455],
#        [36.90688455],
#        [29.13803223],
#        [20.06952735],
#        [32.11713205],
#        [29.25758243],
#        [29.25758243],
#        [39.14555098],
#        [40.38570718],
#        [25.2980884 ],
#        [25.85273019],
#        [24.01986482],
#        [38.87392297],
#        [24.16608403],
#        [31.03120898],
#        [40.76093179],
#        [29.25970701],
#        [25.97401557],
#        [22.32738993],
#        [29.2342063 ],
#        [29.25758243],
#        [23.73582566],
#        [26.73625958],
#        [29.25903962],
#        [36.92874229],
#        [29.25533546],
#        [37.68385915],
#        [29.16134716],
#        [29.2688144 ],
#        [24.0300039 ],
#        [30.65805468],
#        [29.25934271],
#        [34.52302531],
#        [44.24295353],
#        [28.62132356],
#        [25.73542696],
#        [29.25078176],
#        [29.2342063 ],
#        [29.25818862],
#        [36.30493067],
#        [29.26735722],
#        [22.72166944],
#        [29.25970701],
#        [29.25970701],
#        [23.31517954],
#        [29.25988915],
#        [34.2385753 ],
#        [23.39162044],
#        [34.82842608],
#        [44.38284309],
#        [22.49328111],
#        [29.26990729],
#        [29.26699292],
#        [23.3877356 ],
#        [14.18085291],
#        [17.297883  ],
#        [43.66590908],
#        [29.25970701],
#        [36.71745076],
#        [-1.81397799],
#        [44.37270402],
#        [29.25758243],
#        [36.90688455],
#        [38.56648653],
#        [23.37043155],
#        [29.26729602],
#        [23.47087044],
#        [36.90688455],
#        [25.92665713],
#        [31.29643813],
#        [22.3850696 ],
#        [24.03370805],
#        [29.25934271],
#        [44.81999798],
#        [28.62095926],
#        [36.90688455],
#        [34.88525622],
#        [29.25770338],
#        [29.020729  ],
#        [36.94331412],
#        [11.88496696],
#        [29.25533546],
#        [44.81999798],
#        [28.61877349],
#        [31.64562433],
#        [29.27865038],
#        [15.85783238],
#        [32.67038123],
#        [24.00911809],
#        [44.81999798],
#        [21.68900647],
#        [14.02693796],
#        [29.27136447],
#        [28.54939151],
#        [28.06746118],
#        [24.02241489],
#        [37.77857604],
#        [20.00103693],
#        [26.6743293 ],
#        [29.26729602],
#        [29.25818862],
#        [29.2516925 ],
#        [32.82107872],
#        [29.24641021],
#        [29.25533546],
#        [23.31209939],
#        [39.14992252],
#        [29.25715694],
#        [36.94331412],
#        [38.49259569],
#        [29.27883253],
#        [29.24641021],
#        [29.26262137],
#        [-1.17559454],
#        [29.25758243],
#        [34.98927489],
#        [34.36060915],
#        [12.52335041],
#        [29.25934271],
#        [23.60062093],
#        [36.74401926],
#        [32.79376527],
#        [21.73454344],
#        [31.63043784],
#        [39.19582379],
#        [18.33781525],
#        [29.26729602],
#        [22.59645086],
#        [33.64344025],
#        [38.56648653],
#        [-1.81397799],
#        [36.90688455],
#        [31.03120898],
#        [27.73339994],
#        [44.08418179],
#        [29.2342063 ],
#        [19.06163891],
#        [29.25758243],
#        [33.26703646],
#        [44.74713884],
#        [29.24149222],
#        [27.58561681],
#        [23.39168165],
#        [29.22916737],
#        [29.25758243],
#        [29.25758243],
#        [36.10638077],
#        [29.21560213],
#        [29.25758243],
#        [28.58100767],
#        [36.94331412],
#        [29.26990729],
#        [20.17898536],
#        [36.90688455],
#        [38.50716752],
#        [21.85489765],
#        [39.14555098],
#        [29.25970701]])

# %%
ds_test['Прогноз возраста'] = model.predict(X_test)

# %%
ds_test
# Out:
#      Survived  Pclass                            Name  Sex   Age
# 0           0       2        Mr. Leonard Mark Hickman    1  24.0  \
# 1           0       3            Mr. Alexander Radeff    1  27.0
# 2           0       3    Mrs. John (Catherine) Bourke    0  32.0
# 3           0       2     Mr. George Floyd Eitemiller    1  23.0
# 4           0       1       Mr. Arthur Webster Newell    1  58.0
# ..        ...     ...                             ...  ...   ...
# 230         0       2            Rev. Juozas Montvila    1  27.0
# 231         1       1     Miss. Margaret Edith Graham    0  19.0
# 232         0       3  Miss. Catherine Helen Johnston    0   7.0
# 233         1       1            Mr. Karl Howell Behr    1  26.0
# 234         0       3              Mr. Patrick Dooley    1  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard      Fare
# 0                          2                        0   73.5000  \
# 1                          0                        0    7.8958
# 2                          1                        1   15.5000
# 3                          0                        0   13.0000
# 4                          0                        2  113.2750
# ..                       ...                      ...       ...
# 230                        0                        0   13.0000
# 231                        0                        0   30.0000
# 232                        1                        2   23.4500
# 233                        0                        0   30.0000
# 234                        0                        0    7.7500
#
#      Прогноз возраста
# 0           29.454685
# 1           29.257582
# 2           23.596917
# 3           36.906885
# 4           39.917028
# ..                ...
# 230         36.906885
# 231         38.507168
# 232         21.854898
# 233         39.145551
# 234         29.259707
#
# [235 rows x 9 columns]
